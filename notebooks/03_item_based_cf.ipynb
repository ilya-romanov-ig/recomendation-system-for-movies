# %% [markdown]
# # User-Based Callobarative Filtering

# %% [markdown]
# #### User-Item Matrix

# %%
import pandas as pd
import sys

sys.path.append('..')
from src.data_preprocessing import *
from src.utils import eval_model

ratings_df = pd.read_csv('../data/ratings.csv')
movies_df = pd.read_csv('../data/movies.csv')

rating_matrix, user_map, movie_map, user_ids, movie_ids = create_rating_matrix(ratings_df)

# %% [markdown]
# Train test split

# %%
train_matrix, test_matrix = train_test_split_by_user(rating_matrix)

# %% [markdown]
# No feature-tuning IBCF model results

# %%
from src.models import IBCF

model = IBCF()

model.fit(train_matrix)

metrcis, _, _ = eval_model(model, test_matrix)

print(metrcis)
# Out:
# {'rmse': 1.103262485232798, 'mae': 0.7728864218881608}

# %%
models = [
    IBCF(metric='adjusted_cosine', k_similar=10),
    IBCF(metric='cosine', k_similar=10),
    IBCF(metric='adjusted_cosine', k_similar=100),
    IBCF(metric='cosine', k_similar=100),
]

for model in models:
    model.fit(train_matrix)
    metrics, _, _ = eval_model(model, test_matrix)
    print(f"Params: {model.k_similar}, {model.metric} -> [RMSE: {metrics['rmse']}, MAE: {metrcis['mae']}]")
# Out:
# Params: 10, adjusted_cosine -> [RMSE: 1.0989327491109855, MAE: 0.7728864218881608]
# Params: 10, cosine -> [RMSE: 1.099383316442735, MAE: 0.7728864218881608]
# Params: 100, adjusted_cosine -> [RMSE: 1.0918209079267491, MAE: 0.7728864218881608]
# Params: 100, cosine -> [RMSE: 1.1129766741952, MAE: 0.7728864218881608]
